# %%
# Grafico-SEU_NOME.ipynb
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 10, 200)
y = np.sin(x)

plt.figure()
plt.plot(x, y, label="seno(x)")
plt.title("Gráfico de Linha - Exemplo")
plt.xlabel("x")
plt.ylabel("sin(x)")
plt.legend()
plt.show()
